# %%
f = open('input.txt', 'r+')
my_file_data = f.readlines()
f.close()

# %%
#my_file_data

# %%
f = open('input.txt', 'r+')
lines = [line[:-1] for line in f.readlines()]
f.close()

# %%
lines
# Out:
# ['1000000',
#  '5',
#  '8',
#  '6',
#  '3',
#  '5',
#  '9',
#  '7',
#  '9',
#  '9',
#  '2',
#  '1',
#  '9',
#  '7',
#  '9',
#  '1',
#  '3',
#  '8',
#  '8',
#  '8',
#  '2',
#  '7',
#  '2',
#  '1',
#  '3',
#  '5',
#  '7',
#  '7',
#  '1',
#  '9',
#  '8',
#  '8',
#  '3',
#  '6',
#  '2',
#  '9',
#  '1',
#  '2',
#  '2',
#  '1',
#  '4',
#  '2',
#  '3',
#  '2',
#  '1',
#  '3',
#  '3',
#  '3',
#  '5',
#  '7',
#  '5',
#  '9',
#  '3',
#  '8',
#  '2',
#  '2',
#  '6',
#  '4',
#  '9',
#  '4',
#  '5',
#  '8',
#  '8',
#  '1',
#  '9',
#  '9',
#  '2',
#  '1',
#  '1',
#  '7',
#  '8',
#  '5',
#  '8',
#  '8',
#  '8',
#  '7',
#  '5',
#  '6',
#  '1',
#  '6',
#  '3',
#  '7',
#  '8',
#  '1',
#  '5',
#  '3',
#  '6',
#  '7',
#  '9',
#  '1',
#  '7',
#  '4',
#  '9',
#  '6',
#  '8',
#  '7',
#  '9',
#  '8',
#  '7',
#  '3',
#  '1',
#  '4',
#  '1',
#  '3',
#  '6',
#  '3',
#  '9',
#  '2',
#  '1',
#  '4',
#  '4',
#  '6',
#  '3',
#  '6',
#  '7',
#  '4',
#  '6',
#  '8',
#  '8',
#  '9',
#  '9',
#  '1',
#  '2',
#  '7',
# ...
